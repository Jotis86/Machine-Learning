# %% [markdown]
# # 📊 Visualización de Datos - Dataset de Alzheimer
#
# ## 🎨 Introducción a la Visualización de Datos
#
# La **visualización de datos** es una herramienta fundamental en el análisis de datos médicos. En el contexto del Alzheimer, las visualizaciones nos permiten:
#
# ### 🎯 Objetivos de este Notebook:
# - **Identificar patrones visuales** en los datos de Alzheimer
# - **Explorar relaciones** entre variables y el diagnóstico
# - **Detectar tendencias** en factores demográficos y de estilo de vida
# - **Comunicar hallazgos** de forma clara e impactante
# - **Generar hipótesis** para análisis posteriores
#
# ### 🔍 ¿Qué buscamos visualizar?
# - **Distribución de diagnósticos** en la población estudiada
# - **Relaciones entre edad y Alzheimer**
# - **Impacto de factores de estilo de vida** (BMI, ejercicio, dieta)
# - **Diferencias por género y etnia**
# - **Patrones en medidas clínicas** (presión arterial, colesterol)
# - **Síntomas y su relación** con el diagnóstico
#
# ### 💡 Importancia en Medicina:
# En estudios médicos, la visualización es crucial porque permite a los profesionales de la salud identificar rápidamente patrones que podrían no ser evidentes en tablas numéricas, facilitando la toma de decisiones clínicas basadas en evidencia.

# %% [markdown]
# ## 📚 1. Preparación del Entorno
#
# Importamos las librerías necesarias para crear visualizaciones efectivas y profesionales.

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 📁 2. Carga de Datos Limpios
#
# Cargamos el dataset que fue procesado y limpiado en el análisis exploratorio anterior. Este dataset ya contiene las transformaciones necesarias para un análisis efectivo.

# %%
# Load data
df = pd.read_csv('../Data/alzheimers_disease_data_cleaned.csv')

# %%
# Display the first 5 rows of the dataset
df.head(10)
# Out:
#    PatientID    Age  Gender         Ethnicity EducationLevel    BMI Smoking  \
# 0       4751  66-75    Male         Caucasian     Bachelor's  21-25      No
# 1       4752  86-95    Male         Caucasian   No Education  26-30      No
# 2       4753  66-75    Male             Other    High School  15-20      No
# 3       4754  66-75  Female         Caucasian    High School  31-35     Yes
# 4       4755  86-95    Male         Caucasian   No Education  21-25      No
# 5       4756  86-95  Female  African American    High School  31-35      No
# 6       4757  66-75    Male             Other     Bachelor's  36-40     Yes
# 7       4758  66-75    Male         Caucasian    High School  15-20      No
# 8       4759  66-75  Female  African American   No Education  26-30      No
# 9       4760  86-95    Male         Caucasian   No Education  36-40     Yes
#
#   AlcoholConsumption PhysicalActivity DietQuality  ... MemoryComplaints  \
# ...

# %% [markdown]
# ## 📊 3. Visualizaciones Principales

# %%
# 1. Countplot for Diagnosis
plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.countplot(x='Diagnosis', data=df, palette='viridis')

# Add title and labels
ax.set_title('Countplot of Diagnosis', fontsize=20, fontweight='bold')
ax.set_xlabel('Diagnosis', fontsize=16, fontweight='bold')
ax.set_ylabel('Count', fontsize=16, fontweight='bold')

# Set the font size of x-axis and y-axis
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Display the plot
plt.show()

# %%
# 2. Countplot of Diagnoses by Age Range

# Define the order of the age ranges
age_order = ['0-65', '66-75', '76-85', '86-95']

# Convert the 'Age' column to categorical data type
df['Age'] = pd.Categorical(df['Age'], categories=age_order, ordered=True)

# Create a countplot
plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.countplot(x='Age', hue='Diagnosis', data=df, palette='viridis')
ax.set_title('Countplot of Diagnoses by Age Range', fontsize=20, fontweight='bold')
ax.set_xlabel('Age Range', fontsize=16, fontweight='bold')
ax.set_ylabel('Count', fontsize=16, fontweight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Diagnosis', fontsize=12)
plt.show()

# %%
# 3. Bar plot of BMI by Diagnosis

# Define the order of the BMI ranges
bmi_order = ['15-20', '21-25', '26-30', '31-35', '36-40']

# Convert the 'BMI' column to categorical data type
df['BMI'] = pd.Categorical(df['BMI'], categories=bmi_order, ordered=True)

plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.countplot(x='BMI', hue='Diagnosis', data=df, palette='muted')
ax.set_title('Bar Plot of BMI by Diagnosis', fontsize=20, fontweight='bold')
ax.set_xlabel('BMI Range', fontsize=16, fontweight='bold')
ax.set_ylabel('Count', fontsize=16, fontweight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Diagnosis', fontsize=12)
plt.show()

# %%
# 4. Bar plot of Gender by Diagnosis
plt.figure(figsize=(12, 6))
ax = sns.countplot(x='Diagnosis', hue='Gender', data=df, palette='coolwarm')
ax.set_title('Bar Plot of Gender by Diagnosis', fontsize=20,fontweight='bold')
ax.set_xlabel('Diagnosis', fontsize=16,fontweight='bold')
ax.set_ylabel('Count', fontsize=16,fontweight='bold')
plt.legend(title='Gender', labels=['Female', 'Male'], fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# 5. Pie chart for the distribution of alcohol consumption in positive diagnoses
plt.figure(figsize=(14, 7))

df_positive = df[df['Diagnosis'] == 'Yes']

alcohol_counts_positive = df_positive['AlcoholConsumption'].value_counts()
plt.pie(alcohol_counts_positive, labels=alcohol_counts_positive.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('coolwarm', len(alcohol_counts_positive)))
plt.title('Distribution of Alcohol Consumption in Positive Diagnoses', fontweight='bold', fontsize=20)

plt.tight_layout()
plt.show()

# %%
# 6. Bar plot of Ethnicity by Diagnosis
plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.countplot(data=df, x='Diagnosis', hue='Ethnicity', palette='Set2')

# Add title and labels
ax.set_title('Bar Plot of Ethnicity by Diagnosis', fontsize=20, fontweight='bold')
ax.set_xlabel('Diagnosis', fontsize=16, fontweight='bold')
ax.set_ylabel('Count', fontsize=16, fontweight='bold')

# Adjust legend
plt.legend(title='Ethnicity', fontsize=12, title_fontsize=14)

# Adjust tick parameters
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Show plot
plt.show()

# %%
# 7. Bar plot of PhysicalActivity by Diagnosis

# Define the order of the physical activity levels
physical_activity_order = ['0-2', '3-4', '5-6', '7-8', '9-10']

# Convert the 'PhysicalActivity' column to categorical data type
df['PhysicalActivity'] = pd.Categorical(df['PhysicalActivity'], categories=physical_activity_order, ordered=True)

plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.countplot(x='PhysicalActivity', hue='Diagnosis', data=df, palette='viridis')
ax.set_title('Bar Plot of PhysicalActivity by Diagnosis', fontsize=20,fontweight='bold')
ax.set_xlabel('Physical Activity', fontsize=16,fontweight='bold')
ax.set_ylabel('Count', fontsize=16,fontweight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Diagnosis', fontsize=12)
plt.show()

# %%
# 8. Bar plot of Diet Quality by Diagnosis

# Define the order of the diet quality levels
diet_quality_order = ['0-2', '3-4', '5-6', '7-8', '9-10']

# Convert the 'DietQuality' column to categorical data type
df['DietQuality'] = pd.Categorical(df['DietQuality'], categories=diet_quality_order, ordered=True)

plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.countplot(x='DietQuality', hue='Diagnosis', data=df, palette='viridis')
ax.set_title('Bar Plot of Diet Quality by Diagnosis', fontsize=20, fontweight='bold')
ax.set_xlabel('Diet Quality', fontsize=16, fontweight='bold')
ax.set_ylabel('Count', fontsize=16, fontweight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Diagnosis', fontsize=12)
plt.show()

# %%
# 9. Countplot of FamilyHistoryAlzheimers by Diagnosis
plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.countplot(x='FamilyHistoryAlzheimers', hue='Diagnosis', data=df, palette='viridis')
ax.set_title('Countplot of FamilyHistoryAlzheimers by Diagnosis', fontsize=20, fontweight='bold')
ax.set_xlabel('Family History of Alzheimers', fontsize=16, fontweight='bold')
ax.set_ylabel('Count', fontsize=16, fontweight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Diagnosis', fontsize=12)
plt.show()

# %%
# 10. Bar plot of MemoryComplaints by Diagnosis
plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.countplot(x='MemoryComplaints', hue='Diagnosis', data=df, palette='viridis')

# Add title and labels
ax.set_title('Countplot of Memory Complaints by Diagnosis', fontsize=20, fontweight='bold')
ax.set_xlabel('Memory Complaints', fontsize=16, fontweight='bold')
ax.set_ylabel('Count', fontsize=16, fontweight='bold')

# Adjust legend
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Show plot
plt.show()

# %%
# 11. Countplot of BehavioralProblems by Diagnosis
plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.countplot(x='BehavioralProblems', hue='Diagnosis', data=df, palette='viridis')

# Add title and labels
ax.set_title('Countplot of Behavioral Problems by Diagnosis', fontsize=20, fontweight='bold')
ax.set_xlabel('Behavioral Problems', fontsize=16, fontweight='bold')
ax.set_ylabel('Count', fontsize=16, fontweight='bold')

# Adjust legend
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Show plot
plt.show()

# %%
# Load data
df_2 = pd.read_csv('../Data/alzheimers_disease_data.csv')

# Display the first 5 rows of the dataset
df_2.head(10)
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
# 5       4756   86       1          1               1  30.626886        0
# 6       4757   68       0          3               2  38.387622        1
# 7       4758   75       0          0               1  18.776009        0
# 8       4759   72       1          1               0  27.833188        0
# 9       4760   87       0          0               0  35.456302        1
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  MemoryComplaints  \
# 0           13.297218          6.327112     1.347214  ...                 0
# ...

# %%
# 12. Histogram of Age
plt.figure(figsize=(14, 7))
sns.set_style('whitegrid')

ax = sns.histplot(df_2['Age'], bins=30, color='blue', kde=True)

ax.set_title('Histogram of Age', fontsize=20, fontweight='bold')
ax.set_xlabel('Age', fontsize=16, fontweight='bold')
ax.set_ylabel('Count', fontsize=16, fontweight='bold')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.show()

# %%
# 13. Histogram of AlcoholConsumption
plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.histplot(df_2['AlcoholConsumption'], bins=30, kde=True, color='skyblue')
ax.set_title('Histogram of Alcohol Consumption', fontsize=20, fontweight='bold')
ax.set_xlabel('Alcohol Consumption', fontsize=16, fontweight='bold')
ax.set_ylabel('Count', fontsize=16, fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
# 14. KDE plot of CholesterolTotal by Diagnosis
plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.kdeplot(data=df_2, x='CholesterolTotal', hue='Diagnosis', fill=True, palette='viridis')
ax.set_title('KDE plot of CholesterolTotal by Diagnosis', fontsize=20, fontweight='bold')
ax.set_xlabel('Cholesterol Total', fontsize=16, fontweight='bold')
ax.set_ylabel('Density', fontsize=16, fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(title='Diagnosis', fontsize=12)
plt.show()

# %%
# 15. KDE plot of MMSE by Diagnosis
plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.kdeplot(data=df_2, x='MMSE', hue='Diagnosis', fill=True, palette='viridis')
ax.set_title('KDE Plot of MMSE by Diagnosis', fontsize=20, fontweight='bold')
ax.set_xlabel('MMSE Score', fontsize=16, fontweight='bold')
ax.set_ylabel('Density', fontsize=16, fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(title='Diagnosis', fontsize=12, title_fontsize=14)
plt.show()

# %%
# 16. Histogram of Age by Diagnosis
plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
ax = sns.histplot(data=df_2, x='Age', hue='Diagnosis', multiple='stack', bins=30, kde=True, palette='viridis')

ax.set_title('Histogram of Age by Diagnosis', fontsize=20, fontweight='bold')
ax.set_xlabel('Age', fontsize=16, fontweight='bold')
ax.set_ylabel('Count', fontsize=16, fontweight='bold')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.show()
