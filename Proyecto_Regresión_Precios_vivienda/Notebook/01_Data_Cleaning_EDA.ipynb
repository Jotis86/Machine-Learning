# %% [markdown]
# # 📊 Notebook 1: Limpieza de Datos y Análisis Exploratorio de Datos (EDA)
#
# ## 🎯 Objetivos del Notebook
# En este notebook aprenderemos a:
# 1. **Cargar y explorar** nuestro dataset de precios de casas
# 2. **Limpiar los datos** eliminando columnas innecesarias
# 3. **Realizar un análisis exploratorio** para entender la estructura de nuestros datos
# 4. **Identificar patrones** y **valores atípicos**
# 5. **Preparar los datos** para el análisis posterior
#
# ## 📈 ¿Qué es el EDA?
# El **Análisis Exploratorio de Datos** (EDA) es el proceso de analizar datasets para resumir sus características principales, a menudo utilizando métodos estadísticos y visualizaciones. Es un paso crucial antes de aplicar cualquier modelo de machine learning.

# %% [markdown]
# ## 📚 1. Importación de Librerías
#
# Comenzamos importando las librerías necesarias para nuestro análisis:
# - **pandas**: Para manipulación y análisis de datos
# - **numpy**: Para operaciones matemáticas
# - **warnings**: Para suprimir advertencias innecesarias

# %%
# Importamos las librerías necesarias para el análisis exploratorio
import pandas as pd
import numpy as np
import warnings

# Suprimimos las advertencias para una salida más limpia
warnings.filterwarnings("ignore")

print("✅ Librerías importadas correctamente")
# Out:
# ✅ Librerías importadas correctamente

# %% [markdown]
# ## 📂 2. Carga de Datos
#
# Ahora cargaremos nuestro dataset de precios de casas. Este dataset contiene información sobre:
# - **Ingresos promedio del área**
# - **Edad promedio de las casas**
# - **Número promedio de habitaciones**
# - **Número promedio de dormitorios**
# - **Población del área**
# - **Precio de la casa** (nuestra variable objetivo)
# - **Dirección** (que eliminaremos por privacidad)

# %%
# Cargamos el dataset desde el archivo CSV
# Utilizamos una ruta relativa desde la carpeta Notebook hacia la carpeta Data
df = pd.read_csv("../Data/USA_Housing.csv")

print(f"📈 Dataset cargado exitosamente")
print(f"📊 Forma del dataset: {df.shape[0]} filas y {df.shape[1]} columnas")
# Out:
# 📈 Dataset cargado exitosamente
# 📊 Forma del dataset: 5000 filas y 7 columnas

# %% [markdown]
# ## 🔍 3. Exploración Inicial de los Datos
#
# ### 3.1 Primeras Filas del Dataset
# Veamos cómo se ven nuestros datos:

# %%
# Mostramos las primeras 5 filas del dataset
print("🔍 Primeras 5 filas del dataset:")
df.head()
# Out:
# 🔍 Primeras 5 filas del dataset:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\r\nLaurabury, NE 37...
# ...

# %% [markdown]
# ### 3.2 Últimas Filas del Dataset
# También es importante revisar las últimas filas para detectar posibles inconsistencias:

# %%
# Mostramos las últimas 5 filas del dataset
print("🔍 Últimas 5 filas del dataset:")
df.tail()
# Out:
# 🔍 Últimas 5 filas del dataset:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# ...

# %% [markdown]
# ### 3.3 Información General del Dataset
# Obtengamos información detallada sobre nuestros datos:

# %%
# Información detallada sobre el dataset
print("📋 Información detallada del dataset:")
print("=" * 50)
df.info()

print("\n📌 Interpretación:")
print("- Todas las columnas numéricas tienen el mismo número de valores no nulos")
print("- No parece haber valores faltantes en las columnas numéricas")
print("- Los tipos de datos parecen apropiados para nuestro análisis")
# Out:
# 📋 Información detallada del dataset:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB
#
# 📌 Interpretación:
# - Todas las columnas numéricas tienen el mismo número de valores no nulos
# - No parece haber valores faltantes en las columnas numéricas
# - Los tipos de datos parecen apropiados para nuestro análisis

# %% [markdown]
# ### 3.4 Estadísticas Descriptivas
# Las estadísticas descriptivas nos ayudan a entender la distribución de nuestros datos:

# %%
# Estadísticas descriptivas de las variables numéricas
print("📈 Estadísticas descriptivas:")
print("=" * 80)
descripcion = df.describe()
print(descripcion)

print("\n🎯 Insights importantes:")
print(f"• El precio promedio de las casas es: ${descripcion.loc['mean', 'Price']:,.2f}")
print(f"• El precio más bajo es: ${descripcion.loc['min', 'Price']:,.2f}")
print(f"• El precio más alto es: ${descripcion.loc['max', 'Price']:,.2f}")
print(f"• El ingreso promedio del área varía entre ${descripcion.loc['min', 'Avg. Area Income']:,.2f} y ${descripcion.loc['max', 'Avg. Area Income']:,.2f}")
# Out:
# 📈 Estadísticas descriptivas:
# ...
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %% [markdown]
# ## 🧹 4. Limpieza de Datos
#
# ### 4.1 Detección de Valores Faltantes
# Antes de proceder, verifiquemos si hay valores faltantes en nuestro dataset:

# %%
# Verificamos valores faltantes en cada columna
print("🔍 Valores faltantes por columna:")
print("=" * 40)
valores_faltantes = df.isnull().sum()
print(valores_faltantes)

if valores_faltantes.sum() == 0:
    print("\n✅ ¡Excelente! No hay valores faltantes en el dataset")
else:
    print(f"\n⚠️  Se encontraron {valores_faltantes.sum()} valores faltantes en total")
# Out:
# 🔍 Valores faltantes por columna:
# ...
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64
#
# ✅ ¡Excelente! No hay valores faltantes en el dataset

# %% [markdown]
# ### 4.2 Eliminación de Columnas Innecesarias
# La columna 'Address' contiene información que:
# 1. **No aporta valor predictivo** para nuestro modelo
# 2. **No es útil** para el análisis estadístico
#
# Por tanto, la eliminaremos:

# %%
# Verificamos qué columnas tenemos antes de la limpieza
print("📋 Columnas antes de la limpieza:")
print(list(df.columns))

# Eliminamos la columna 'Address' ya que no aporta valor predictivo
df_clean = df.drop(columns=["Address"])

print("\n📋 Columnas después de la limpieza:")
print(list(df_clean.columns))

print(f"\n✅ Dataset limpio creado con {df_clean.shape[0]} filas y {df_clean.shape[1]} columnas")
# Out:
# 📋 Columnas antes de la limpieza:
# ['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms', 'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address']
#
# 📋 Columnas después de la limpieza:
# ['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms', 'Avg. Area Number of Bedrooms', 'Area Population', 'Price']
#
# ✅ Dataset limpio creado con 5000 filas y 6 columnas

# %% [markdown]
# ## 📊 5. Análisis Exploratorio Detallado
#
# ### 5.1 Análisis de la Variable Objetivo (Precio)
# Analicemos la distribución de nuestra variable objetivo:

# %%
# Análisis detallado de la variable precio
print("🏠 Análisis de la Variable Objetivo: PRECIO")
print("=" * 50)

precio_stats = df_clean['Price'].describe()
print("📈 Estadísticas del Precio:")
for stat, value in precio_stats.items():
    print(f"  {stat.capitalize()}: ${value:,.2f}")

# Calculamos algunos estadísticos adicionales
q1 = df_clean['Price'].quantile(0.25)
q3 = df_clean['Price'].quantile(0.75)
iqr = q3 - q1

print(f"\n📊 Análisis de Cuartiles:")
print(f"  Q1 (25%): ${q1:,.2f}")
print(f"  Q3 (75%): ${q3:,.2f}")
print(f"  IQR (Rango Intercuartílico): ${iqr:,.2f}")

# Detección de valores atípicos usando el método IQR
limite_inferior = q1 - 1.5 * iqr
limite_superior = q3 + 1.5 * iqr
outliers = df_clean[(df_clean['Price'] < limite_inferior) | (df_clean['Price'] > limite_superior)]

print(f"\n🔍 Detección de Valores Atípicos:")
print(f"  Límite inferior: ${limite_inferior:,.2f}")
print(f"  Límite superior: ${limite_superior:,.2f}")
print(f"  Número de outliers: {len(outliers)} ({len(outliers)/len(df_clean)*100:.2f}% del total)")
# Out:
# 🏠 Análisis de la Variable Objetivo: PRECIO
# ...
# 📈 Estadísticas del Precio:
#   Count: $5,000.00
#   Mean: $1,232,072.65
#   Std: $353,117.63
#   Min: $15,938.66
#   25%: $997,577.14
#   50%: $1,232,669.38
#   75%: $1,471,210.20
#   Max: $2,469,065.59
#
# 📊 Análisis de Cuartiles:
#   Q1 (25%): $997,577.14
#   Q3 (75%): $1,471,210.20
#   IQR (Rango Intercuartílico): $473,633.07
#
# 🔍 Detección de Valores Atípicos:
#   Límite inferior: $287,127.53
#   Límite superior: $2,181,659.81
#   Número de outliers: 35 (0.70% del total)

# %% [markdown]
# ### 5.2 Análisis de las Variables Predictoras
# Analicemos cada una de nuestras variables independientes:

# %%
# Análisis de las variables predictoras
print("🏗️ Análisis de Variables Predictoras")
print("=" * 60)

variables_predictoras = ['Avg. Area Income', 'Avg. Area House Age', 
                        'Avg. Area Number of Rooms', 'Avg. Area Number of Bedrooms', 
                        'Area Population']

for var in variables_predictoras:
    print(f"\n📊 {var}:")
    stats = df_clean[var].describe()
    print(f"  • Promedio: {stats['mean']:,.2f}")
    print(f"  • Mediana: {stats['50%']:,.2f}")
    print(f"  • Desviación estándar: {stats['std']:,.2f}")
    print(f"  • Rango: {stats['min']:,.2f} - {stats['max']:,.2f}")
    
    # Coeficiente de variación
    cv = (stats['std'] / stats['mean']) * 100
    print(f"  • Coeficiente de variación: {cv:.2f}%")
# Out:
# 🏗️ Análisis de Variables Predictoras
# ...
#
# 📊 Avg. Area Income:
#   • Promedio: 68,583.11
#   • Mediana: 68,804.29
#   • Desviación estándar: 10,657.99
#   • Rango: 17,796.63 - 107,701.75
#   • Coeficiente de variación: 15.54%
#
# 📊 Avg. Area House Age:
#   • Promedio: 5.98
#   • Mediana: 5.97
#   • Desviación estándar: 0.99
#   • Rango: 2.64 - 9.52
#   • Coeficiente de variación: 16.59%
#
# 📊 Avg. Area Number of Rooms:
#   • Promedio: 6.99
#   • Mediana: 7.00
#   • Desviación estándar: 1.01
#   • Rango: 3.24 - 10.76
#   • Coeficiente de variación: 14.39%
#
# 📊 Avg. Area Number of Bedrooms:
#   • Promedio: 3.98
#   • Mediana: 4.05
#   • Desviación estándar: 1.23
#   • Rango: 2.00 - 6.50
#   • Coeficiente de variación: 31.00%
#
# 📊 Area Population:
#   • Promedio: 36,163.52
#   • Mediana: 36,199.41
#   • Desviación estándar: 9,925.65
#   • Rango: 172.61 - 69,621.71
#   • Coeficiente de variación: 27.45%

# %% [markdown]
# ### 5.3 Análisis de Correlación
# Veamos cómo se relacionan nuestras variables entre sí:

# %%
# Matriz de correlación
print("🔗 Matriz de Correlación")
print("=" * 40)

correlacion = df_clean.corr()
print(correlacion.round(3))

# Análisis de correlación con la variable objetivo
print("\n🎯 Correlación con el Precio (Variable Objetivo):")
correlacion_precio = correlacion['Price'].sort_values(ascending=False)
print(correlacion_precio.round(3))

print("\n📝 Interpretación de Correlaciones:")
for var, corr in correlacion_precio.items():
    if var != 'Price':
        if abs(corr) > 0.7:
            fuerza = "muy fuerte"
        elif abs(corr) > 0.5:
            fuerza = "fuerte"
        elif abs(corr) > 0.3:
            fuerza = "moderada"
        else:
            fuerza = "débil"
        
        direccion = "positiva" if corr > 0 else "negativa"
        print(f"  • {var}: Correlación {fuerza} {direccion} ({corr:.3f})")
# Out:
# 🔗 Matriz de Correlación
# ...
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                         1.000               -0.002
# Avg. Area House Age                     -0.002                1.000
# Avg. Area Number of Rooms               -0.011               -0.009
# Avg. Area Number of Bedrooms             0.020                0.006
# Area Population                         -0.016               -0.019
# Price                                    0.640                0.453
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                                 -0.011
# Avg. Area House Age                              -0.009
# Avg. Area Number of Rooms                         1.000
# Avg. Area Number of Bedrooms                      0.463
# Area Population                                   0.002
# Price                                             0.336
#
# ...

# %% [markdown]
# ## 💾 6. Guardado de Datos Limpios
#
# Finalmente, guardamos nuestros datos limpios para uso en los siguientes notebooks:

# %%
# Guardamos el dataset limpio
df_clean.to_csv("../Data/USA_Housing_Clean.csv", index=False)

print("💾 Dataset limpio guardado como 'USA_Housing_Clean.csv'")
print(f"📊 Resumen final del dataset limpio:")
print(f"  • Filas: {df_clean.shape[0]:,}")
print(f"  • Columnas: {df_clean.shape[1]}")
print(f"  • Variables predictoras: {len(variables_predictoras)}")
print(f"  • Variable objetivo: Price")
print(f"  • Valores faltantes: {df_clean.isnull().sum().sum()}")
# Out:
# 💾 Dataset limpio guardado como 'USA_Housing_Clean.csv'
# 📊 Resumen final del dataset limpio:
#   • Filas: 5,000
#   • Columnas: 6
#   • Variables predictoras: 5
#   • Variable objetivo: Price
#   • Valores faltantes: 0

# %% [markdown]
# ## 📋 7. Resumen y Conclusiones
#
# ### ✅ Lo que hemos logrado:
# 1. **Cargamos exitosamente** el dataset de precios de casas
# 2. **Exploramos la estructura** de nuestros datos
# 3. **Limpiamos el dataset** eliminando la columna de direcciones
# 4. **Analizamos las distribuciones** de todas las variables
# 5. **Calculamos correlaciones** para entender las relaciones entre variables
# 6. **Identificamos patrones** importantes en los datos
# 7. **Guardamos el dataset limpio** para análisis posteriores
#
# ### 🎯 Hallazgos clave:
# - El dataset no tiene valores faltantes
# - Las variables muestran correlaciones interesantes con el precio
# - Los datos parecen estar en buen estado para el modelado
#
# ### 📈 Próximos pasos:
# - **Notebook 2**: Visualizaciones detalladas de los datos
# - **Notebook 3**: Construcción y evaluación del modelo de machine learning
#
# ---
# **🎓 Aprendizaje clave**: El EDA es fundamental antes de cualquier modelado. Nos permite entender nuestros datos, detectar problemas y tomar decisiones informadas sobre el preprocesamiento.
